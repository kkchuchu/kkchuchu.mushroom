# %%
import random
import math
import matplotlib.pyplot as plt

# %%
BEANS = 100000

l = (1 if math.pow(random.random(), 2) + math.pow(random.random(), 2) <= 1 else 0 for i in range(0, BEANS))
4 * reduce(lambda x, y : x + y, l)/float(BEANS)
# Out:
# 3.1456

# %%
X = [i for i in range(1000, 100000, 1000)]
Y = [4 * reduce(lambda i, j : i + j, 
                (1 if math.pow(random.random(), 2) + math.pow(random.random(), 2) <= 1 else 0 
                 for i in range(0, x)
                )
               )/float(x) 
     for x in X
    ]

plt.plot(X, Y)
plt.ylabel('pi value')
plt.xlabel('counter')
plt.show()
